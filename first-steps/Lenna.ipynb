# %%
from PIL import Image
import numpy as np
import scipy

# %%
img = Image.open('Lenna.png')
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512 at 0x22A71560DA0>

# %%
img_data = np.array(img)
print(img_data)
# Out:
# [[[226 137 125]
#   [226 137 125]
#   [223 137 133]
#   ...
#   [230 148 122]
#   [221 130 110]
#   [200  99  90]]
#
#  [[226 137 125]
#   [226 137 125]
#   [223 137 133]
#   ...
#   [230 148 122]
#   [221 130 110]
#   [200  99  90]]
#
#  [[226 137 125]
#   [226 137 125]
#   [223 137 133]
#   ...
#   [230 148 122]
#   [221 130 110]
#   [200  99  90]]
#
#  ...
#
#  [[ 84  18  60]
#   [ 84  18  60]
#   [ 92  27  58]
#   ...
#   [173  73  84]
#   [172  68  76]
#   [177  62  79]]
#
#  [[ 82  22  57]
#   [ 82  22  57]
#   [ 96  32  62]
#   ...
#   [179  70  79]
#   [181  71  81]
#   [185  74  81]]
#
#  [[ 82  22  57]
#   [ 82  22  57]
#   [ 96  32  62]
#   ...
#   [179  70  79]
#   [181  71  81]
#   [185  74  81]]]

# %%
new_img_data = img_data.copy()
new_img_data[:,:,0::2] = 0
new_image = Image.fromarray(new_img_data)
new_image
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x22A72AA2E10>

# %%
bw_1 = np.average(img_data,2)
bw_2 = np.reshape(bw_1,(512,512,1))
bw_img_data = np.repeat(bw_2,3,axis = 2)
bw_img_data = bw_img_data.astype(np.uint8)
bw_img_data.shape 
print(bw_img_data)
bw_img = Image.fromarray(bw_img_data)
bw_img
# Out:
# [[[162 162 162]
#   [162 162 162]
#   [164 164 164]
#   ...
#   [166 166 166]
#   [153 153 153]
#   [129 129 129]]
#
#  [[162 162 162]
#   [162 162 162]
#   [164 164 164]
#   ...
#   [166 166 166]
#   [153 153 153]
#   [129 129 129]]
#
#  [[162 162 162]
#   [162 162 162]
#   [164 164 164]
#   ...
#   [166 166 166]
#   [153 153 153]
#   [129 129 129]]
#
#  ...
#
#  [[ 54  54  54]
#   [ 54  54  54]
#   [ 59  59  59]
#   ...
#   [110 110 110]
#   [105 105 105]
#   [106 106 106]]
#
#  [[ 53  53  53]
#   [ 53  53  53]
#   [ 63  63  63]
#   ...
#   [109 109 109]
#   [111 111 111]
#   [113 113 113]]
#
#  [[ 53  53  53]
#   [ 53  53  53]
#   [ 63  63  63]
#   ...
#   [109 109 109]
#   [111 111 111]
#   [113 113 113]]]
# <PIL.Image.Image image mode=RGB size=512x512 at 0x22A741926A0>

# %%
def kernel(img_d,w):
    return skipy.ndimage.filters.convolve(img_d,w)
